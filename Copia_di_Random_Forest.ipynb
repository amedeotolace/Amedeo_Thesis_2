# %% [markdown]
# <a href="https://colab.research.google.com/github/amedeotolace/Amedeo_Thesis_2/blob/main/Copia_di_Random_Forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow

# %%
# !pip install tensorflow_datasets

# %%
# !pip install tensorflow tensorflow_decision_forests

# %%
# !pip install datapackage

# %%
# !pip install pandas

# %%
import datapackage
import pandas as pd

data_url = 'https://datahub.io/machine-learning/kddcup99/datapackage.json'

# to load Data Package into storage
package = datapackage.Package(data_url)

# to load only tabular data
resources = package.resources
for resource in resources:
    if resource.tabular:
        df = pd.read_csv(resource.descriptor['path'])
        print (df)
# Out:
#         duration protocol_type service flag  src_bytes  dst_bytes  land  \
# 0              0           tcp    http   SF        181       5450     0
# 1              0           tcp    http   SF        239        486     0
# 2              0           tcp    http   SF        235       1337     0
# 3              0           tcp    http   SF        219       1337     0
# 4              0           tcp    http   SF        217       2032     0
# ...          ...           ...     ...  ...        ...        ...   ...
# 494015         0           tcp    http   SF        310       1881     0
# 494016         0           tcp    http   SF        282       2286     0
# 494017         0           tcp    http   SF        203       1200     0
# 494018         0           tcp    http   SF        291       1200     0
# 494019         0           tcp    http   SF        219       1234     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# ...

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

ds_train, ds_test = tfds.load('kddcup99', split=['train','test'], as_supervised=None)
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# ...
# Generating train examples...:   0%|          | 0/4898431 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/kddcup99/1.0.1.incomplete44OY6G/kddcup99-train.tfrecord*...:   0%|        …
# Generating test examples...:   0%|          | 0/311029 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/kddcup99/1.0.1.incomplete44OY6G/kddcup99-test.tfrecord*...:   0%|         …
# Dataset kddcup99 downloaded and prepared to /root/tensorflow_datasets/kddcup99/1.0.1. Subsequent calls will reuse this data.

# %%
# !pip install keras
